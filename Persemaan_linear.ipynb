# %% [markdown]
# # Apa yang dimaksud persaamaan linear

# %% [markdown]
# persamaan Linear adalah salah satu persamaan dari ilmu aljabar di mana persamaan ini sukunya mengandung konstanta dengan variabel tunggal

# %% [markdown]
# # buat dua persamaan linear dengan dua variable

# %% [markdown]
# ![geogebra-export.png](data:image/png;base64,...)
